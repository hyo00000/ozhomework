# %% [markdown]
# 컴퓨터 기초 지식을 의미하는 CS(Computer science)는<br>
# 코딩 테스트와 함께 기술 면접에서 지원자에게 필수적으로 요구합니다.<br>
#
# 수업 내용 중 기술 면접에 자주 나오는 질문 3가지와 기본적으로 알아야 할 내용 과제로 선정했습니다.<br>
#
# 관련 내용에 대해서는 구글링 또는 관련 서적을 통해 상세히 공부하시고<br>
# 답변은 최대한 핵심만 담아 간결하게 작성해주세요<br>
#
# 기술 블로그를 운영 중이신 경우<br>
# 답변 내용을 기술 블로그에 작성하신 후 링크를 답변에 남겨주셔도 됩니다.<br>

# %% [markdown]
# -----

# %% [markdown]
# [문제1]
#
# Python의 변수 할당 개념을 다른 언어와 비교해 설명해주세요

# %% [markdown]
# 동적타이핑이란 변수의 타입을 명시할 필요없이 변수에 어떤 값을 할당하면 그에 따라 타입이 결정되는 것을 말한다.
# python은 이와 같은 동적 타이핑을 사용해서 어떤 값을 할당할 때, 해당 값을 저장하는 객체를 메모리에 생성한다.
# 그 후 변수는 이 객체의 메모리 주소를 참조한다.
# 이때 변수는 참조 할당되는데 변수가 값 자체가 아니라 값이 저장된 객체를 참조함을 나타낸다.
# 따라서 동일한 객체를 여러번 수가 참조할 수 있다.
# javascript는 python과 유사하지만
# C와 Java에서는 정적타이핑으로 값을 직접 저장하는 방식을 사용하여, 변수 간의 값 복사가 이루어집니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# Python의 실수형(float) 계산 시 오차가 발생하는 이유에 대해 간단히 설명해 주세요

# %%
컴퓨터는 실수를 IEEE754와 같은 부동 소수점 표현 방식으로 저장한다. 
이진수로 표현해야 하는 특성상 실수는 이진수로 정확히 표현하기 어렵기 때문에 근사값으로 저장이 되는데 
그로인해 계산 과정에서 작은 오차가 누적되는 경우가 생긴다.

#파이썬에서는 실수형 계산 시 발생하는 오차는 부동 소수점 표현 방식(실수를 IEEE754와 같이 저장)의 한계 때문에 발생한다.
#이는 컴퓨터의 이진수 표현에서 정확한 소수점 이하 값을 표현하기 어렵기 때문에 발생하는 현상이다.

# %% [markdown]
# ----

# %% [markdown]
# [문제3]
#
# 슬라이싱에 대해 간단히 설명해주세요

# %%
슬라이싱은 콜론(:)을 사용해 시퀀스 테이터 타입의 일부를 추출하는 방법입니다.
기본문법은 sequence[start:stop:step] 으로
각각의 매개변수는 
start : 슬라이스의 시작 인덱스(포함)
stop : 슬라이스의 끝 인덱스 (불포함)
step : 슬라이스 할 간견
이 있다.

슬라이싱 문법을 사용하여 슬리이싱 범위와 간격을 지정할 수 있으며
start와 stop을 생략하거나 음수 인덱스를 사용 할 수도 있고
step의 경우 간격을 조절하거나 역순으로 슬라이싱 할 수 있다.
